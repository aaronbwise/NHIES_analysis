# %% [markdown]
# ## Namibia 2006-07 DHS Salt analysis
# ### 02 November 2020

# %%
from pathlib import Path
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", None)

# %%
fn = 'nmhr51fl.dta'
path = Path.cwd().joinpath('data', fn)
df = pd.read_stata(path)
df.shape
# Out:
# (9200, 2862)

# %%
df.hv234.value_counts(dropna=False)
# Out:
# NaN    9200
# Name: hv234, dtype: int64

# %%
df.sh143.value_counts(dropna=False)
# Out:
# NaN                 8171
# shop/supermarket     870
# salt pan              76
# open market           73
# other                  9
# dk                     1
# Name: sh143, dtype: int64

# %%
df.sh142.value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-d13892e29b76> in <module>
# ----> 1 df.sh142.value_counts(dropna=False)
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sh142'
